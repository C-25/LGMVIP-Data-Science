# %% [markdown]
# <a href="https://colab.research.google.com/github/C-25/LGMVIP-Data-Science/blob/main/LGMVIP_DATA_SCIENCE_TASK_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LGMVIP TASK-4**
# # **LEVEL - BEGINNER**
# # **IMAGE TO PENCIL SKETCH WITH PYTHON**
# # **AUTHOR - CHIRAG GHOSH**

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("bridge.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=780x408 at 0x7F0532049CD0>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=780x408 at 0x7F05319B4710>

# %%
img_invert = cv2.bitwise_not(img_gray)
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=780x408 at 0x7F05319B4B10>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21,21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=780x408 at 0x7F0532051A10>

# %%
def dodgeV2(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=780x408 at 0x7F05319C9BD0>

# %%
cv2_imshow(img)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=RGB size=780x408 at 0x7F05319B6BD0>
# <PIL.Image.Image image mode=L size=780x408 at 0x7F05319C0210>
